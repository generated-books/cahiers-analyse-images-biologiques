# %% [markdown]
# # Translating a Jupyter book about Bio-image Analsis
# In this notebook we will translate an existing Jupyter book about Bio-image Analsis from English to another language using a large language model. We use Claude 3.5 Sonnet.

# %%
import anthropic
import openai
import datetime
import os
from pathlib import Path
from functools import partial
from IPython.display import Markdown, display
import json
import shutil

openai.__version__, anthropic.__version__
# Out:
# ('1.30.1', '0.29.0')

# %% [markdown]
# ## Defining the content of the book
# First we specify the source content of the book and the target language.

# %%
source_dir = "../BioImageAnalysisNotebooks/"

# %%
target_language = "French"

# %% [markdown]
# We will also specify the location where to store the book:

# %%
base_dir = ""
repository_url = "https://github.com/generated-books/bio-bildanalyse-notebooks"

# %% [markdown]
# We will use this language model to generate the book:

# %%
model = "claude-3-5-sonnet-20240620"

# %% [markdown]
# ## Helper functions
# Here we create some helper functions for prompting and for file format handling.

# %%
def prompt_chatGPT(message:str, model="gpt-4o-2024-05-13"):
    """
    A prompt helper function that sends a message to openAI
    and returns only the text response.
    """
    import os
    import openai
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
        
    # setup connection to the LLM
    client = openai.OpenAI()
    
    # submit prompt
    response = client.chat.completions.create(
        model=model,
        messages=message
    )
    
    # extract answer
    return response.choices[0].message.content

# %%
def prompt_claude(message:str, model="claude-3-5-sonnet-20240620"):
    """
    A prompt helper function that sends a message to anthropic
    and returns only the text response.

    Example models: claude-3-5-sonnet-20240620 or claude-3-opus-20240229
    """
    import os
    from anthropic import Anthropic
    
    # convert message in the right format if necessary
    if isinstance(message, str):
        message = [{"role": "user", "content": message}]
        
    # setup connection to the LLM
    client = Anthropic()
    
    message = client.messages.create(
        max_tokens=4096,
        messages=message,
        model=model,
    )

    # extract answer
    return message.content[0].text

# %%
if "gpt" in model:
    prompt = partial(prompt_gpt, model=model)
else:
    prompt = partial(prompt_claude, model=model)

# %%
def prompt_with_memory(message:str):
    """
    This function allows to use an LLMs in a chat-mode. 
    The LLM is equipped with some memory, 
    so that we can refer back for former conversation steps.
    """
    
    # convert message in the right format and store it in memory
    question = {"role": "user", "content": message}
    chat_history.append(question)
    
    # receive answer
    response = prompt(chat_history)
    
    # convert answer in the right format and store it in memory
    answer = {"role": "assistant", "content": response}
    chat_history.append(answer)
    
    return response

# %%
def is_valid_json(test_string):
    """This function returns if a string is formatted json."""
    import json
    try:
        json.loads(test_string)
        return True
    except:
        return False

def ensure_json(notebook):
    """This function makes sure that the passed notebook is indeed a json-formatted ipynb file."""
    if is_valid_json(notebook):
        return notebook
        
    return prompt(f"""
Take the following text and extract the Jupyter 
notebook ipynb/json from it:

{notebook}

Make sure the output is in ipynb/json format. 
Respond only the JSON content.
""").strip("```json").strip("```python").strip("```")

# %% [markdown]
# ## Context
# Here we provide some context to the language model. As gpt4 and claude have different APIs for providing system messages, we instead use this message to start the conversation.

# %%
system_message = f"""
You are going to translate text from English to {target_language}. 
Do not modify any Python code. Do not translate it. Also do not translate strings in Python code.
In case you receive markdown files or Jupyter notebooks in JSON format, leave the structure of the document as it is and just translate the English text to {target_language}.

Confirm this with "ok".
"""

chat_history = [{"role": "user", "content": system_message}, {"role": "assistant", "content": "ok"}]

# %% [markdown]
# ## Generating the book
# Here we start generating the notebooks for the content listed in the table of contents.

# %%
def translate_file(source_filename, target_filename):
    # remove outputs from jupyter notebooks (because it might be too big otherwise)
    if source_filename.endswith(".ipynb"): # notebook
        # Load the notebook as a JSON object
        with open(source_filename, 'r', encoding='utf-8') as f:
            notebook_content = json.load(f)
    
        # Iterate through the cells and erase the outputs
        for cell in notebook_content['cells']:
            if cell['cell_type'] == 'code':
                cell['outputs'] = []
                cell['execution_count'] = None
    
        file_content = json.dumps(notebook_content, indent=1)
    else:
        with open(source_filename, 'r', encoding='utf-8') as f:
            file_content = f.read()

    # run LLM translation
    translated_content = prompt_with_memory(file_content).strip("'").strip('"')

    # copy code outputs from source to target file
    if source_filename.endswith(".ipynb"): # notebook
        with open(source_filename, 'r', encoding='utf-8') as f:
            notebook_content = json.load(f)
        
        #print(translated_content)
        
        old_content = notebook_content
        new_content = json.loads(translated_content)
    
        for o, n in zip(old_content['cells'], new_content['cells']):
            if "outputs" in o.keys():
                n['outputs'] = o['outputs']
                n['execution_count'] = o['execution_count']
    
        translated_str = json.dumps(new_content, indent=1)
    else:
        translated_str = translated_content

    # save result to target file
    with open(target_filename, 'w', encoding='utf-8') as file:
        file.write(translated_str)

# %%
memory_len = len(chat_history)
for root, dirs, files in os.walk(source_dir):
    for file in files:
        if not "-checkpoint" in file and not "Untitled" in file and not "_build" in root and not ".git/" in root and not ".git\\" in root and not "generator.ipynb" in file:

            source_file = os.path.join(root, file).replace("\\", "/")
            target_file = source_file.replace(source_dir, base_dir).replace("\\", "/")

            # make sure target folder exists
            directory = Path(target_file).parent
            os.makedirs(directory, exist_ok=True)

            if not os.path.exists(target_file): # avoid re-generating the same files
                try:
                    if file.endswith(".md") or file.endswith(".ipynb"):
                        
                        chat_history = chat_history[:memory_len]
                        
                        print(f"Translating {source_file} to {target_file}")
                        translate_file(source_file, target_file)
                    else:
                        print(f"Copying {source_file} to {target_file}")
                        shutil.copy(source_file, target_file)
                except:
                    print("Error")
# Out:
# Copying ../BioImageAnalysisNotebooks/.gitignore to .gitignore
# Copying ../BioImageAnalysisNotebooks/build.sh to build.sh
# Copying ../BioImageAnalysisNotebooks/clean.sh to clean.sh
# Translating ../BioImageAnalysisNotebooks/CODE-OF-CONDUCT.md to CODE-OF-CONDUCT.md
# Translating ../BioImageAnalysisNotebooks/CONTRIBUTING.md to CONTRIBUTING.md
# Copying ../BioImageAnalysisNotebooks/LICENSE-BSD3 to LICENSE-BSD3
# Copying ../BioImageAnalysisNotebooks/LICENSE-CC-BY to LICENSE-CC-BY
# Translating ../BioImageAnalysisNotebooks/readme.md to readme.md
# Copying ../BioImageAnalysisNotebooks/requirements.txt to requirements.txt
# Copying ../BioImageAnalysisNotebooks/.git/COMMIT_EDITMSG to .git/COMMIT_EDITMSG
# Copying ../BioImageAnalysisNotebooks/.git/config to .git/config
# Copying ../BioImageAnalysisNotebooks/.git/description to .git/description
# Copying ../BioImageAnalysisNotebooks/.git/FETCH_HEAD to .git/FETCH_HEAD
# Copying ../BioImageAnalysisNotebooks/.git/HEAD to .git/HEAD
# Copying ../BioImageAnalysisNotebooks/.git/index to .git/index
# Copying ../BioImageAnalysisNotebooks/.git/packed-refs to .git/packed-refs
# Copying ../BioImageAnalysisNotebooks/.github/workflows/book.yml to .github/workflows/book.yml
# Copying ../BioImageAnalysisNotebooks/data/banana0020.tif to data/banana0020.tif
# Copying ../BioImageAnalysisNotebooks/data/banana_source.txt to data/banana_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_20P1_POS0007_D_1UL.csv to data/BBBC007_20P1_POS0007_D_1UL.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_20P1_POS0010_D_1UL.csv to data/BBBC007_20P1_POS0010_D_1UL.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_analysis.csv to data/BBBC007_analysis.csv
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_data_source.txt to data/BBBC007_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC022_image_data_source.txt to data/BBBC022_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/Bead_Image1_crop.tif to data/Bead_Image1_crop.tif
# Copying ../BioImageAnalysisNotebooks/data/binary_arm.tif to data/binary_arm.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs.tif to data/blobs.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_annotated.tif to data/blobs_annotated.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_annotations.tif to data/blobs_annotations.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_classifier.cl to data/blobs_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_labeled.tif to data/blobs_labeled.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_object_classifier.cl to data/blobs_object_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_object_segmenter.cl to data/blobs_object_segmenter.cl
# Copying ../BioImageAnalysisNotebooks/data/blobs_otsu.tif to data/blobs_otsu.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_otsu_watershed.tif to data/blobs_otsu_watershed.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_sparse_labels.tif to data/blobs_sparse_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_statistics.csv to data/blobs_statistics.csv
# Copying ../BioImageAnalysisNotebooks/data/blobs_stitching1_overlap40.tif to data/blobs_stitching1_overlap40.tif
# Copying ../BioImageAnalysisNotebooks/data/blobs_stitching2_overlap40.tif to data/blobs_stitching2_overlap40.tif
# Copying ../BioImageAnalysisNotebooks/data/BMP4blastocystC3-cropped_resampled_8bit.tif to data/BMP4blastocystC3-cropped_resampled_8bit.tif
# Copying ../BioImageAnalysisNotebooks/data/BMP4blastocystC3-cropped_resampled_8bit_image_data_source.txt to data/BMP4blastocystC3-cropped_resampled_8bit_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BPAE_actin.tif to data/BPAE_actin.tif
# Copying ../BioImageAnalysisNotebooks/data/BPAE_mito.tif to data/BPAE_mito.tif
# Copying ../BioImageAnalysisNotebooks/data/BPAE_nuclei.tif to data/BPAE_nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/branchoid.ply to data/branchoid.ply
# Copying ../BioImageAnalysisNotebooks/data/CalibZAPWfixed_000154_max.tif to data/CalibZAPWfixed_000154_max.tif
# Copying ../BioImageAnalysisNotebooks/data/cancer_cell_migration_crop.tif to data/cancer_cell_migration_crop.tif
# Translating ../BioImageAnalysisNotebooks/data/cancer_cell_migration_source.md to data/cancer_cell_migration_source.md
# Copying ../BioImageAnalysisNotebooks/data/cancer_cell_migration_voronoi_otsu_labeling_crop.tif to data/cancer_cell_migration_voronoi_otsu_labeling_crop.tif
# Copying ../BioImageAnalysisNotebooks/data/cells3d_annotations.csv to data/cells3d_annotations.csv
# Copying ../BioImageAnalysisNotebooks/data/cells3d_image_source.txt to data/cells3d_image_source.txt
# Copying ../BioImageAnalysisNotebooks/data/cells3d_membranes.tif to data/cells3d_membranes.tif
# Copying ../BioImageAnalysisNotebooks/data/cells3d_nuclei.tif to data/cells3d_nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/cells_annotation.tif to data/cells_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/DeconvolutionSampleVerticalGrid1AU-crop.tif to data/DeconvolutionSampleVerticalGrid1AU-crop.tif
# Copying ../BioImageAnalysisNotebooks/data/drugs.csv to data/drugs.csv
# Copying ../BioImageAnalysisNotebooks/data/E39.lif [E4] - 2.png to data/E39.lif [E4] - 2.png
# Copying ../BioImageAnalysisNotebooks/data/E39.lif [E4] - 2_image_data_source.txt to data/E39.lif [E4] - 2_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/embryos_grey.tif to data/embryos_grey.tif
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0-1.tif-image data source.txt to data/EM_C_6_c0-1.tif-image data source.txt
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0.ome.tif to data/EM_C_6_c0.ome.tif
# Copying ../BioImageAnalysisNotebooks/data/EM_C_6_c0.tif to data/EM_C_6_c0.tif
# Copying ../BioImageAnalysisNotebooks/data/experiments.csv to data/experiments.csv
# Copying ../BioImageAnalysisNotebooks/data/Haase_MRT_tfl3d1.tif to data/Haase_MRT_tfl3d1.tif
# Copying ../BioImageAnalysisNotebooks/data/hela-cells-8bit.tif to data/hela-cells-8bit.tif
# Copying ../BioImageAnalysisNotebooks/data/hela-cells.tif to data/hela-cells.tif
# Copying ../BioImageAnalysisNotebooks/data/images.csv to data/images.csv
# Copying ../BioImageAnalysisNotebooks/data/label_annotation.tif to data/label_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/label_map_with_index_gaps.tif to data/label_map_with_index_gaps.tif
# Copying ../BioImageAnalysisNotebooks/data/Lund-25MB.tif to data/Lund-25MB.tif
# Copying ../BioImageAnalysisNotebooks/data/Lund_000500_resampled-cropped.tif to data/Lund_000500_resampled-cropped.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm.model.cl to data/maize_clsm.model.cl
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm.tif to data/maize_clsm.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_annotation.tif to data/maize_clsm_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_labels.tif to data/maize_clsm_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/maize_clsm_source.txt to data/maize_clsm_source.txt
# Copying ../BioImageAnalysisNotebooks/data/maize_cslm_object_classifier.cl to data/maize_cslm_object_classifier.cl
# Copying ../BioImageAnalysisNotebooks/data/measurements.csv to data/measurements.csv
# Copying ../BioImageAnalysisNotebooks/data/membrane2d.tif to data/membrane2d.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane2d_merge_annotation.tif to data/membrane2d_merge_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane2d_oversegmented.tif to data/membrane2d_oversegmented.tif
# Copying ../BioImageAnalysisNotebooks/data/membranes_2d.tif to data/membranes_2d.tif
# Copying ../BioImageAnalysisNotebooks/data/membranes_2d_sparse_labels.tif to data/membranes_2d_sparse_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane_2d_timelapse.tif to data/membrane_2d_timelapse.tif
# Copying ../BioImageAnalysisNotebooks/data/membrane_2d_timelapse_image_data_source.txt to data/membrane_2d_timelapse_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/mitosis.tif to data/mitosis.tif
# Copying ../BioImageAnalysisNotebooks/data/mitosis_mod.tif to data/mitosis_mod.tif
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_bvtkn4mm_source.txt to data/mri_fruit_bvtkn4mm_source.txt
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_bvtnk4mm.jpg to data/mri_fruit_bvtnk4mm.jpg
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_sxm89b3x.jpg to data/mri_fruit_sxm89b3x.jpg
# Copying ../BioImageAnalysisNotebooks/data/mri_fruit_sxm89b3x_source.txt to data/mri_fruit_sxm89b3x_source.txt
# Copying ../BioImageAnalysisNotebooks/data/Multi_analysis.csv to data/Multi_analysis.csv
# Copying ../BioImageAnalysisNotebooks/data/nuclei.tif to data/nuclei.tif
# Copying ../BioImageAnalysisNotebooks/data/overview.csv to data/overview.csv
# Copying ../BioImageAnalysisNotebooks/data/P1_H_C3H_M004_17-cropped-license.txt to data/P1_H_C3H_M004_17-cropped-license.txt
# Copying ../BioImageAnalysisNotebooks/data/P1_H_C3H_M004_17-cropped.tif to data/P1_H_C3H_M004_17-cropped.tif
# Copying ../BioImageAnalysisNotebooks/data/plate1_1_013 [Well 5, Field 1 (Spot 5)].png to data/plate1_1_013 [Well 5, Field 1 (Spot 5)].png
# Copying ../BioImageAnalysisNotebooks/data/plate1_1_013 [Well 5, Field 1 (Spot 5)]_image_data_source.txt to data/plate1_1_013 [Well 5, Field 1 (Spot 5)]_image_data_source.txt
# Translating ../BioImageAnalysisNotebooks/data/Platynereis_source.md to data/Platynereis_source.md
# Copying ../BioImageAnalysisNotebooks/data/Platynereis_tp7_channel1_rescaled(256x256x103)_gt.tif to data/Platynereis_tp7_channel1_rescaled(256x256x103)_gt.tif
# Copying ../BioImageAnalysisNotebooks/data/Platynereis_tp7_channel1_rescaled(256x256x103)_voronoi_otsu_label_image.tif to data/Platynereis_tp7_channel1_rescaled(256x256x103)_voronoi_otsu_label_image.tif
# Copying ../BioImageAnalysisNotebooks/data/psf.tif to data/psf.tif
# Copying ../BioImageAnalysisNotebooks/data/PupalWing.czi to data/PupalWing.czi
# Copying ../BioImageAnalysisNotebooks/data/PupalWing_image_data_source.txt to data/PupalWing_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/real_cat.png to data/real_cat.png
# Copying ../BioImageAnalysisNotebooks/data/real_cat_mic_mask.tif to data/real_cat_mic_mask.tif
# Copying ../BioImageAnalysisNotebooks/data/reference_labels.tif to data/reference_labels.tif
# Copying ../BioImageAnalysisNotebooks/data/Results.csv to data/Results.csv
# Copying ../BioImageAnalysisNotebooks/data/rounding_assay.tif to data/rounding_assay.tif
# Copying ../BioImageAnalysisNotebooks/data/rounding_assay_source.txt to data/rounding_assay_source.txt
# Copying ../BioImageAnalysisNotebooks/data/short_table.csv to data/short_table.csv
# Copying ../BioImageAnalysisNotebooks/data/syntetic_cells.tif to data/syntetic_cells.tif
# Copying ../BioImageAnalysisNotebooks/data/syntetic_cells_merge_annotation.tif to data/syntetic_cells_merge_annotation.tif
# Copying ../BioImageAnalysisNotebooks/data/zfish_eye.tif to data/zfish_eye.tif
# Copying ../BioImageAnalysisNotebooks/data/zfish_eye_source.txt to data/zfish_eye_source.txt
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0002.tif to data/banana/banana0002.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0003.tif to data/banana/banana0003.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0004.tif to data/banana/banana0004.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0005.tif to data/banana/banana0005.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0006.tif to data/banana/banana0006.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0007.tif to data/banana/banana0007.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0008.tif to data/banana/banana0008.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0009.tif to data/banana/banana0009.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0010.tif to data/banana/banana0010.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0011.tif to data/banana/banana0011.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0012.tif to data/banana/banana0012.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0013.tif to data/banana/banana0013.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0014.tif to data/banana/banana0014.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0015.tif to data/banana/banana0015.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0016.tif to data/banana/banana0016.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0017.tif to data/banana/banana0017.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0018.tif to data/banana/banana0018.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0019.tif to data/banana/banana0019.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0020.tif to data/banana/banana0020.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0021.tif to data/banana/banana0021.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0022.tif to data/banana/banana0022.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0023.tif to data/banana/banana0023.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0024.tif to data/banana/banana0024.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0025.tif to data/banana/banana0025.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/banana0026.tif to data/banana/banana0026.tif
# Copying ../BioImageAnalysisNotebooks/data/banana/image_source.txt to data/banana/image_source.txt
# Translating ../BioImageAnalysisNotebooks/data/BBBC007/readme.md to data/BBBC007/readme.md
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 1).tif to data/BBBC007/images/A9 p5d (cropped 1).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 2).tif to data/BBBC007/images/A9 p5d (cropped 2).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 3).tif to data/BBBC007/images/A9 p5d (cropped 3).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/images/A9 p5d (cropped 4).tif to data/BBBC007/images/A9 p5d (cropped 4).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 1).tif to data/BBBC007/masks/A9 p5d (cropped 1).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 2).tif to data/BBBC007/masks/A9 p5d (cropped 2).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 3).tif to data/BBBC007/masks/A9 p5d (cropped 3).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007/masks/A9 p5d (cropped 4).tif to data/BBBC007/masks/A9 p5d (cropped 4).tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/17P1_POS0013_D_1UL.tif to data/BBBC007_batch/17P1_POS0013_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0005_D_1UL.tif to data/BBBC007_batch/20P1_POS0005_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0007_D_1UL.tif to data/BBBC007_batch/20P1_POS0007_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/20P1_POS0010_D_1UL.tif to data/BBBC007_batch/20P1_POS0010_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/A9 p7d.tif to data/BBBC007_batch/A9 p7d.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_batch/AS_09125_040701150004_A02f00d0.tif to data/BBBC007_batch/AS_09125_040701150004_A02f00d0.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/17P1_POS0013_D_1UL.tif to data/BBBC007_sparse_instance_annotation/17P1_POS0013_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0005_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0005_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0007_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0007_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/20P1_POS0010_D_1UL.tif to data/BBBC007_sparse_instance_annotation/20P1_POS0010_D_1UL.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/A9 p7d.tif to data/BBBC007_sparse_instance_annotation/A9 p7d.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC007_sparse_instance_annotation/AS_09125_040701150004_A02f00d0.tif to data/BBBC007_sparse_instance_annotation/AS_09125_040701150004_A02f00d0.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC022/IXMtest_A02_s9.tif to data/BBBC022/IXMtest_A02_s9.tif
# Copying ../BioImageAnalysisNotebooks/data/BBBC022/IXMtest_A02_s9_image_data_source.txt to data/BBBC022/IXMtest_A02_s9_image_data_source.txt
# Copying ../BioImageAnalysisNotebooks/data/BBBC038/0bf4b1.tif to data/BBBC038/0bf4b1.tif
# Translating ../BioImageAnalysisNotebooks/docs/imprint.md to docs/imprint.md
# Translating ../BioImageAnalysisNotebooks/docs/intro.md to docs/intro.md
# Copying ../BioImageAnalysisNotebooks/docs/logo.png to docs/logo.png
# Copying ../BioImageAnalysisNotebooks/docs/references.bib to docs/references.bib
# Copying ../BioImageAnalysisNotebooks/docs/requirements.txt to docs/requirements.txt
# Copying ../BioImageAnalysisNotebooks/docs/_config.yml to docs/_config.yml
# Copying ../BioImageAnalysisNotebooks/docs/_toc.yml to docs/_toc.yml
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/glossary.md to docs/01_introduction/glossary.md
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/hello_world.png to docs/01_introduction/hello_world.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_jupyter.png to docs/01_introduction/install_jupyter.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_mambaforge.png to docs/01_introduction/install_mambaforge.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/install_mambaforge2.png to docs/01_introduction/install_mambaforge2.png
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/readme.md to docs/01_introduction/readme.md
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/start_jupyter_lab.png to docs/01_introduction/start_jupyter_lab.png
# Copying ../BioImageAnalysisNotebooks/docs/01_introduction/test_opencl.png to docs/01_introduction/test_opencl.png
# Translating ../BioImageAnalysisNotebooks/docs/01_introduction/trailer.ipynb to docs/01_introduction/trailer.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/01_our_first_juptyer_notebook.ipynb to docs/02_python_basics/01_our_first_juptyer_notebook.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/02_Math_in_python.ipynb to docs/02_python_basics/02_Math_in_python.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/03_Dont_try_this_at_home.ipynb to docs/02_python_basics/03_Dont_try_this_at_home.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/04_Basic_types.ipynb to docs/02_python_basics/04_Basic_types.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05a_cropping_lists.ipynb to docs/02_python_basics/05a_cropping_lists.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05b_sorting_lists.ipynb to docs/02_python_basics/05b_sorting_lists.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/05_lists_tuples.ipynb to docs/02_python_basics/05_lists_tuples.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/06_Dictionaries_and_tables.ipynb to docs/02_python_basics/06_Dictionaries_and_tables.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/07_Conditions.ipynb to docs/02_python_basics/07_Conditions.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/08_loops.ipynb to docs/02_python_basics/08_loops.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/09_custom_functions.ipynb to docs/02_python_basics/09_custom_functions.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/10_Import_packages.ipynb to docs/02_python_basics/10_Import_packages.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/02_python_basics/cell_execution_number.png to docs/02_python_basics/cell_execution_number.png
# Translating ../BioImageAnalysisNotebooks/docs/02_python_basics/readme.md to docs/02_python_basics/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/custom_libraries.ipynb to docs/03_advanced_python/custom_libraries.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/functional_parameters.ipynb to docs/03_advanced_python/functional_parameters.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/03_advanced_python/login.png to docs/03_advanced_python/login.png
# Copying ../BioImageAnalysisNotebooks/docs/03_advanced_python/my_library.py to docs/03_advanced_python/my_library.py
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/numba.ipynb to docs/03_advanced_python/numba.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/owncloud.ipynb to docs/03_advanced_python/owncloud.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/parallelization.ipynb to docs/03_advanced_python/parallelization.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/partial.ipynb to docs/03_advanced_python/partial.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/03_advanced_python/readme.md to docs/03_advanced_python/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/divide_and_rule.ipynb to docs/04_sustainable_code/divide_and_rule.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/dont_repeat_yourself.ipynb to docs/04_sustainable_code/dont_repeat_yourself.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/keep_it_short_and_simple.ipynb to docs/04_sustainable_code/keep_it_short_and_simple.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/magic_numbers.ipynb to docs/04_sustainable_code/magic_numbers.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/readable_code.ipynb to docs/04_sustainable_code/readable_code.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/04_sustainable_code/readme.md to docs/04_sustainable_code/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/image_file_formats.ipynb to docs/12a_image_file_formats/image_file_formats.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/opening_czi_files.ipynb to docs/12a_image_file_formats/opening_czi_files.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/opening_images.ipynb to docs/12a_image_file_formats/opening_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/opening_images_using_aicsimageio.ipynb to docs/12a_image_file_formats/opening_images_using_aicsimageio.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/opening_lif_files.ipynb to docs/12a_image_file_formats/opening_lif_files.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/opening_tif_folders.ipynb to docs/12a_image_file_formats/opening_tif_folders.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/readme.md to docs/12a_image_file_formats/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/12a_image_file_formats/tiled_image_file_formats_zarr.ipynb to docs/12a_image_file_formats/tiled_image_file_formats_zarr.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/exploring_bioimage_archive.ipynb to docs/12b_remote_files/exploring_bioimage_archive.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/exploring_doi.ipynb to docs/12b_remote_files/exploring_doi.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/exploring_idr.ipynb to docs/12b_remote_files/exploring_idr.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/exploring_zenodo.ipynb to docs/12b_remote_files/exploring_zenodo.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/12b_remote_files/login.png to docs/12b_remote_files/login.png
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/nextcloud.ipynb to docs/12b_remote_files/nextcloud.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12b_remote_files/readme.md to docs/12b_remote_files/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/01_Images_as_arrays.ipynb to docs/12_image_analysis_basics/01_Images_as_arrays.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/02_Opening_visualizing_images.ipynb to docs/12_image_analysis_basics/02_Opening_visualizing_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/03_Computing_with_images.ipynb to docs/12_image_analysis_basics/03_Computing_with_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/04_Cropping_images.ipynb to docs/12_image_analysis_basics/04_Cropping_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/05_Masking_images.ipynb to docs/12_image_analysis_basics/05_Masking_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/06_multi_channel_image_data.ipynb to docs/12_image_analysis_basics/06_multi_channel_image_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/analyse_banana_data_set.ipynb to docs/12_image_analysis_basics/analyse_banana_data_set.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/brightness_and_contrast.ipynb to docs/12_image_analysis_basics/brightness_and_contrast.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/readme.md to docs/12_image_analysis_basics/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/12_image_analysis_basics/skeletonization.ipynb to docs/12_image_analysis_basics/skeletonization.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/data_generator.py to docs/14_machine_learning_basics/data_generator.py
# Translating ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/readme.md to docs/14_machine_learning_basics/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/scaling.ipynb to docs/14_machine_learning_basics/scaling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/supervised_machine_learning.ipynb to docs/14_machine_learning_basics/supervised_machine_learning.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/unsupervised_machine_learning.ipynb to docs/14_machine_learning_basics/unsupervised_machine_learning.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/14_machine_learning_basics/__pycache__/data_generator.cpython-39.pyc to docs/14_machine_learning_basics/__pycache__/data_generator.cpython-39.pyc
# Translating ../BioImageAnalysisNotebooks/docs/15_gpu_acceleration/clesperanto.ipynb to docs/15_gpu_acceleration/clesperanto.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/15_gpu_acceleration/further_reading.md to docs/15_gpu_acceleration/further_reading.md
# Translating ../BioImageAnalysisNotebooks/docs/15_gpu_acceleration/memory_management.ipynb to docs/15_gpu_acceleration/memory_management.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/15_gpu_acceleration/readme.md to docs/15_gpu_acceleration/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/15_gpu_acceleration/why_GPU_acceleration.ipynb to docs/15_gpu_acceleration/why_GPU_acceleration.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/16_3d_image_visualization/05_napari.ipynb to docs/16_3d_image_visualization/05_napari.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/16_3d_image_visualization/10_nd_image_data.ipynb to docs/16_3d_image_visualization/10_nd_image_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/16_3d_image_visualization/inspecting_3d_images.ipynb to docs/16_3d_image_visualization/inspecting_3d_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/16_3d_image_visualization/napari.ipynb to docs/16_3d_image_visualization/napari.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/16_3d_image_visualization/readme.md to docs/16_3d_image_visualization/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/deconvolution_pycudadecon.ipynb to docs/18a_deconvolution/deconvolution_pycudadecon.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/deconvolution_pycudadecon_test.ipynb to docs/18a_deconvolution/deconvolution_pycudadecon_test.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/extract_psf.ipynb to docs/18a_deconvolution/extract_psf.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/extract_psf_backup.ipynb to docs/18a_deconvolution/extract_psf_backup.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/introduction_deconvolution.ipynb to docs/18a_deconvolution/introduction_deconvolution.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/readme.md to docs/18a_deconvolution/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/18a_deconvolution/richardson_lucy_deconvolution.ipynb to docs/18a_deconvolution/richardson_lucy_deconvolution.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/01_Filtering.ipynb to docs/18_image_filtering/01_Filtering.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/02_noise_removal.ipynb to docs/18_image_filtering/02_noise_removal.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/03_background_removal.ipynb to docs/18_image_filtering/03_background_removal.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/convolution.ipynb to docs/18_image_filtering/convolution.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/divide_by_gaussian.ipynb to docs/18_image_filtering/divide_by_gaussian.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/edge_detection_and_enhancement.ipynb to docs/18_image_filtering/edge_detection_and_enhancement.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/filter_overview.ipynb to docs/18_image_filtering/filter_overview.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/image_filtering.ipynb to docs/18_image_filtering/image_filtering.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/readme.md to docs/18_image_filtering/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/simpleitk.ipynb to docs/18_image_filtering/simpleitk.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/18_image_filtering/structuring_elements.ipynb to docs/18_image_filtering/structuring_elements.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/affine_transforms_clesperanto.ipynb to docs/19_spatial_transforms/affine_transforms_clesperanto.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/affine_transforms_cupy.ipynb to docs/19_spatial_transforms/affine_transforms_cupy.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/affine_transforms_scikit_image.ipynb to docs/19_spatial_transforms/affine_transforms_scikit_image.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/affine_transforms_scipy.ipynb to docs/19_spatial_transforms/affine_transforms_scipy.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/coordinate_systems.ipynb to docs/19_spatial_transforms/coordinate_systems.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/cropping.ipynb to docs/19_spatial_transforms/cropping.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/crop_images_for_stitching.ipynb to docs/19_spatial_transforms/crop_images_for_stitching.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/downsampling_with_denoising.ipynb to docs/19_spatial_transforms/downsampling_with_denoising.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/readme.md to docs/19_spatial_transforms/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/scaling.ipynb to docs/19_spatial_transforms/scaling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/scaling_coordinate_lists.ipynb to docs/19_spatial_transforms/scaling_coordinate_lists.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/stitching_linear_blending.ipynb to docs/19_spatial_transforms/stitching_linear_blending.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/19_spatial_transforms/transpose.ipynb to docs/19_spatial_transforms/transpose.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/apoc_object_segmenter.ipynb to docs/20a_pixel_classification/apoc_object_segmenter.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/apoc_pixel_classifier.ipynb to docs/20a_pixel_classification/apoc_pixel_classifier.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/apoc_probability_mapper.ipynb to docs/20a_pixel_classification/apoc_probability_mapper.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/apoc_train_on_folders.ipynb to docs/20a_pixel_classification/apoc_train_on_folders.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/feature_stacks.ipynb to docs/20a_pixel_classification/feature_stacks.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/multichannel_images.ipynb to docs/20a_pixel_classification/multichannel_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/readme.md to docs/20a_pixel_classification/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/scikit_learn_random_forest_pixel_classifier.ipynb to docs/20a_pixel_classification/scikit_learn_random_forest_pixel_classifier.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/selecting_features.ipynb to docs/20a_pixel_classification/selecting_features.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc1.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc1.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc10.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc10.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc11.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc11.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc2.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc2.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc3.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc3.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc4.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc4.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc5.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc5.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc6.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc6.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc7.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc7.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc8.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc8.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc9.png to docs/20a_pixel_classification/interactive_pixel_classification/apoc9.png
# Copying ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/apoc_object_segmentation.mp4 to docs/20a_pixel_classification/interactive_pixel_classification/apoc_object_segmentation.mp4
# Translating ../BioImageAnalysisNotebooks/docs/20a_pixel_classification/interactive_pixel_classification/readme.md to docs/20a_pixel_classification/interactive_pixel_classification/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/20b_deep_learning/cellpose.ipynb to docs/20b_deep_learning/cellpose.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20b_deep_learning/readme.md to docs/20b_deep_learning/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/20b_deep_learning/stardist.ipynb to docs/20b_deep_learning/stardist.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/erode_connected_labels.ipynb to docs/20h_segmentation_post_processing/erode_connected_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/identify_labels_touching_background.ipynb to docs/20h_segmentation_post_processing/identify_labels_touching_background.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/inner_and_outer_cell_borders.ipynb to docs/20h_segmentation_post_processing/inner_and_outer_cell_borders.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/label_edges.ipynb to docs/20h_segmentation_post_processing/label_edges.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/merge_annotated_labels.ipynb to docs/20h_segmentation_post_processing/merge_annotated_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/merge_labels.ipynb to docs/20h_segmentation_post_processing/merge_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/merge_objects_using_machine_learning.ipynb to docs/20h_segmentation_post_processing/merge_objects_using_machine_learning.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/merging_labels_based_on_centroid_distance.ipynb to docs/20h_segmentation_post_processing/merging_labels_based_on_centroid_distance.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/merging_labels_based_on_edge_to_edge_distance.ipynb to docs/20h_segmentation_post_processing/merging_labels_based_on_edge_to_edge_distance.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/mimicking_imagej_watershed.ipynb to docs/20h_segmentation_post_processing/mimicking_imagej_watershed.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/mode_filter.ipynb to docs/20h_segmentation_post_processing/mode_filter.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/morphological_operations.ipynb to docs/20h_segmentation_post_processing/morphological_operations.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/object_selector.cl to docs/20h_segmentation_post_processing/object_selector.cl
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/open_close_labels.ipynb to docs/20h_segmentation_post_processing/open_close_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/readme.md to docs/20h_segmentation_post_processing/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/refine_cell_segmentation.ipynb to docs/20h_segmentation_post_processing/refine_cell_segmentation.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/remove_labels_on_image_edges.ipynb to docs/20h_segmentation_post_processing/remove_labels_on_image_edges.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/select_labels.ipynb to docs/20h_segmentation_post_processing/select_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/select_labels_based_on_size.ipynb to docs/20h_segmentation_post_processing/select_labels_based_on_size.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/sequential_labeling.ipynb to docs/20h_segmentation_post_processing/sequential_labeling.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/simulated_cell_clumb.py to docs/20h_segmentation_post_processing/simulated_cell_clumb.py
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/smooth_labels.ipynb to docs/20h_segmentation_post_processing/smooth_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20h_segmentation_post_processing/splitting_touching_objects.ipynb to docs/20h_segmentation_post_processing/splitting_touching_objects.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/06_Introduction_to_image_segmentation.ipynb to docs/20_image_segmentation/06_Introduction_to_image_segmentation.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/07_Thresholding.ipynb to docs/20_image_segmentation/07_Thresholding.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/08a_split_touching_objects.ipynb to docs/20_image_segmentation/08a_split_touching_objects.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/08_binary_mask_refinement.ipynb to docs/20_image_segmentation/08_binary_mask_refinement.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/09a_gauss_otsu_labeling.ipynb to docs/20_image_segmentation/09a_gauss_otsu_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/09_connected_component_labeling.ipynb to docs/20_image_segmentation/09_connected_component_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/10_touching_objects_labeling.ipynb to docs/20_image_segmentation/10_touching_objects_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/11a_eroded_otsu_labeling.ipynb to docs/20_image_segmentation/11a_eroded_otsu_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/11_voronoi_otsu_labeling.ipynb to docs/20_image_segmentation/11_voronoi_otsu_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/binarization.ipynb to docs/20_image_segmentation/binarization.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/prevent_leaking_labels.ipynb to docs/20_image_segmentation/prevent_leaking_labels.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/readme.md to docs/20_image_segmentation/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/segmentation_2d_membranes.ipynb to docs/20_image_segmentation/segmentation_2d_membranes.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/Segmentation_3D.ipynb to docs/20_image_segmentation/Segmentation_3D.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/terminology.ipynb to docs/20_image_segmentation/terminology.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/20_image_segmentation/test.cl to docs/20_image_segmentation/test.cl
# Translating ../BioImageAnalysisNotebooks/docs/20_image_segmentation/voronoi_otsu_labeling_for_binary_images.ipynb to docs/20_image_segmentation/voronoi_otsu_labeling_for_binary_images.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/21_surface_processing/branchoid.py to docs/21_surface_processing/branchoid.py
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/connected_component_labeling.ipynb to docs/21_surface_processing/connected_component_labeling.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/creating_surfaces.ipynb to docs/21_surface_processing/creating_surfaces.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/quality_measurements.ipynb to docs/21_surface_processing/quality_measurements.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/readme.md to docs/21_surface_processing/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/saving_and_loading_surfaces.ipynb to docs/21_surface_processing/saving_and_loading_surfaces.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/smoothing_and_simplifying_surfaces.ipynb to docs/21_surface_processing/smoothing_and_simplifying_surfaces.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/surfaces_and_point_clouds.ipynb to docs/21_surface_processing/surfaces_and_point_clouds.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/surfaces_to_images.ipynb to docs/21_surface_processing/surfaces_to_images.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/surface_vertex_classification.ipynb to docs/21_surface_processing/surface_vertex_classification.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/tabular_quality_measurements.ipynb to docs/21_surface_processing/tabular_quality_measurements.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/21_surface_processing/visualizing_surfaces.ipynb to docs/21_surface_processing/visualizing_surfaces.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/comparison_of_measurements_from_different_libraries.ipynb to docs/22_feature_extraction/comparison_of_measurements_from_different_libraries.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/count_blobs.ipynb to docs/22_feature_extraction/count_blobs.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/distance_along_line.ipynb to docs/22_feature_extraction/distance_along_line.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/distance_features.ipynb to docs/22_feature_extraction/distance_features.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/distance_from_center.ipynb to docs/22_feature_extraction/distance_from_center.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/intensities_along_lines.ipynb to docs/22_feature_extraction/intensities_along_lines.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/measure_intensity_on_label_edges.ipynb to docs/22_feature_extraction/measure_intensity_on_label_edges.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/quantitative_measurements.ipynb to docs/22_feature_extraction/quantitative_measurements.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/readme.md to docs/22_feature_extraction/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/shape_descriptors_based_on_neighborhood_graphs.ipynb to docs/22_feature_extraction/shape_descriptors_based_on_neighborhood_graphs.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/statistics_with_nyxus.ipynb to docs/22_feature_extraction/statistics_with_nyxus.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/statistics_with_pyclesperanto.ipynb to docs/22_feature_extraction/statistics_with_pyclesperanto.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/statistics_with_scikit_image.ipynb to docs/22_feature_extraction/statistics_with_scikit_image.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/22_feature_extraction/statistics_with_simpleitk.ipynb to docs/22_feature_extraction/statistics_with_simpleitk.ipynb
# Error
# Copying ../BioImageAnalysisNotebooks/docs/22_feature_extraction/schematics/feature_categories.png to docs/22_feature_extraction/schematics/feature_categories.png
# Translating ../BioImageAnalysisNotebooks/docs/23_blob_detection/blog_dog_log_doh.ipynb to docs/23_blob_detection/blog_dog_log_doh.ipynb
# ...
# Translating ../BioImageAnalysisNotebooks/docs/34_timelapse_analysis/intensity_over_time.ipynb to docs/34_timelapse_analysis/intensity_over_time.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/34_timelapse_analysis/readme.md to docs/34_timelapse_analysis/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/34_timelapse_analysis/tracking.ipynb to docs/34_timelapse_analysis/tracking.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/35_parameter_optimization/label_image_optimizer.ipynb to docs/35_parameter_optimization/label_image_optimizer.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/35_parameter_optimization/membrane_segmentation.ipynb to docs/35_parameter_optimization/membrane_segmentation.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/35_parameter_optimization/optimization_basics.ipynb to docs/35_parameter_optimization/optimization_basics.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/35_parameter_optimization/readme.md to docs/35_parameter_optimization/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/3ways/load_an_show_an_image.ipynb to docs/3ways/load_an_show_an_image.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/3ways/load_image_and_measure_shape_of_nuclei_in_3d.ipynb to docs/3ways/load_image_and_measure_shape_of_nuclei_in_3d.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/3ways/parametric_maps.ipynb to docs/3ways/parametric_maps.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/3ways/readme.md to docs/3ways/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/3ways/resave_skimage_example_data.ipynb to docs/3ways/resave_skimage_example_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40a_sql/group_by.ipynb to docs/40a_sql/group_by.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40a_sql/join.ipynb to docs/40a_sql/join.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40a_sql/make_test_data.ipynb to docs/40a_sql/make_test_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40a_sql/readme.md to docs/40a_sql/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/40a_sql/select.ipynb to docs/40a_sql/select.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/append_tables.ipynb to docs/40_tabular_data_wrangling/append_tables.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/explore_dataset.ipynb to docs/40_tabular_data_wrangling/explore_dataset.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/handling_NaNs.ipynb to docs/40_tabular_data_wrangling/handling_NaNs.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/introduction_dataframes.ipynb to docs/40_tabular_data_wrangling/introduction_dataframes.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/pivot_tables.ipynb to docs/40_tabular_data_wrangling/pivot_tables.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/readme.md to docs/40_tabular_data_wrangling/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/select_rows_and_columns.ipynb to docs/40_tabular_data_wrangling/select_rows_and_columns.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/summarizing_subsets.ipynb to docs/40_tabular_data_wrangling/summarizing_subsets.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/40_tabular_data_wrangling/tidy_data.ipynb to docs/40_tabular_data_wrangling/tidy_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/basic_descriptive_statistics.ipynb to docs/41_descriptive_statistics/basic_descriptive_statistics.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/Bland_altman_analysis.ipynb to docs/41_descriptive_statistics/Bland_altman_analysis.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/bland_altman_on_folders_of_images.ipynb to docs/41_descriptive_statistics/bland_altman_on_folders_of_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/bland_altman_simulated_data.ipynb to docs/41_descriptive_statistics/bland_altman_simulated_data.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/descriptive_statistics_label_images.ipynb to docs/41_descriptive_statistics/descriptive_statistics_label_images.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/Pingouin_stats.ipynb to docs/41_descriptive_statistics/Pingouin_stats.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/readme.md to docs/41_descriptive_statistics/readme.md
# Copying ../BioImageAnalysisNotebooks/docs/41_descriptive_statistics/utils.py to docs/41_descriptive_statistics/utils.py
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/distributions.ipynb to docs/44_hypothesis_testing/distributions.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/Equivalence_testing.ipynb to docs/44_hypothesis_testing/Equivalence_testing.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/my_statistics_functions.py to docs/44_hypothesis_testing/my_statistics_functions.py
# Copying ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/patients.py to docs/44_hypothesis_testing/patients.py
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/readme.md to docs/44_hypothesis_testing/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/T-Test.ipynb to docs/44_hypothesis_testing/T-Test.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/Testing_curation_time.ipynb to docs/44_hypothesis_testing/Testing_curation_time.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/Testing_tomato_ripen_time.ipynb to docs/44_hypothesis_testing/Testing_tomato_ripen_time.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/The_p-value.ipynb to docs/44_hypothesis_testing/The_p-value.ipynb
# Copying ../BioImageAnalysisNotebooks/docs/44_hypothesis_testing/tomatoes.py to docs/44_hypothesis_testing/tomatoes.py
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/dens_map.ipynb to docs/47_clustering/dens_map.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/feature_selection.ipynb to docs/47_clustering/feature_selection.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/readme.md to docs/47_clustering/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/tissue_clustering.ipynb to docs/47_clustering/tissue_clustering.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/trailer.ipynb to docs/47_clustering/trailer.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/umap.ipynb to docs/47_clustering/umap.ipynb
# Error
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/clustering.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/clustering.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/hdbscan_clusters_plot.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/hdbscan_clusters_plot.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/kmeans_clusters_plot.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/kmeans_clusters_plot.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/measure.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/measure.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/multi-select-manual-clustering.gif to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/multi-select-manual-clustering.gif
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plotting_time-lapse_data_as_movie.gif to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plotting_time-lapse_data_as_movie.gif
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plot_interactive.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plot_interactive.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plot_plain.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/plot_plain.png
# Translating ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/readme.md to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/readme.md
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/screencast.gif to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/screencast.gif
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/select_in_layer.gif to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/select_in_layer.gif
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/starting_point.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/starting_point.png
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/timelapse_manual_clustering_tips.gif to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/timelapse_manual_clustering_tips.gif
# Copying ../BioImageAnalysisNotebooks/docs/47_clustering/interactive_dimensionality_reduction_and_clustering/umap.png to docs/47_clustering/interactive_dimensionality_reduction_and_clustering/umap.png
# Translating ../BioImageAnalysisNotebooks/docs/51_plotting/multivariate_views.ipynb to docs/51_plotting/multivariate_views.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/51_plotting/plotting_distributions.ipynb to docs/51_plotting/plotting_distributions.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/51_plotting/plotting_matplotlib.ipynb to docs/51_plotting/plotting_matplotlib.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/51_plotting/plotting_seaborn.ipynb to docs/51_plotting/plotting_seaborn.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/51_plotting/readme.md to docs/51_plotting/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/60_data_visualization/overlay_text_on_image.ipynb to docs/60_data_visualization/overlay_text_on_image.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/60_data_visualization/parametric_maps.ipynb to docs/60_data_visualization/parametric_maps.ipynb
# Error
# Translating ../BioImageAnalysisNotebooks/docs/60_data_visualization/quantitative_neighbor_maps.ipynb to docs/60_data_visualization/quantitative_neighbor_maps.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/60_data_visualization/readme.md to docs/60_data_visualization/readme.md
# Translating ../BioImageAnalysisNotebooks/docs/70_workflows/napari-assistant.md to docs/70_workflows/napari-assistant.md
# Translating ../BioImageAnalysisNotebooks/docs/70_workflows/napari_workflows.ipynb to docs/70_workflows/napari_workflows.ipynb
# Translating ../BioImageAnalysisNotebooks/docs/70_workflows/notebook_export.md to docs/70_workflows/notebook_export.md
# Translating ../BioImageAnalysisNotebooks/docs/70_workflows/readme.md to docs/70_workflows/readme.md
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks.mp4 to docs/70_workflows/images/export_notebooks.mp4
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks01.jpg to docs/70_workflows/images/export_notebooks01.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks02.jpg to docs/70_workflows/images/export_notebooks02.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks03.jpg to docs/70_workflows/images/export_notebooks03.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks04.jpg to docs/70_workflows/images/export_notebooks04.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks05.jpg to docs/70_workflows/images/export_notebooks05.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks06.jpg to docs/70_workflows/images/export_notebooks06.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks07.jpg to docs/70_workflows/images/export_notebooks07.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks08.jpg to docs/70_workflows/images/export_notebooks08.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/export_notebooks09.jpg to docs/70_workflows/images/export_notebooks09.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/hela_cells_screenshot.png to docs/70_workflows/images/hela_cells_screenshot.png
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/install_package01.png to docs/70_workflows/images/install_package01.png
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant.mp4 to docs/70_workflows/images/napari-assistant.mp4
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant01.jpg to docs/70_workflows/images/napari-assistant01.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant02.jpg to docs/70_workflows/images/napari-assistant02.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant03.jpg to docs/70_workflows/images/napari-assistant03.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant04.jpg to docs/70_workflows/images/napari-assistant04.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant05.jpg to docs/70_workflows/images/napari-assistant05.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant06.jpg to docs/70_workflows/images/napari-assistant06.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant07.jpg to docs/70_workflows/images/napari-assistant07.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant08.jpg to docs/70_workflows/images/napari-assistant08.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant09.jpg to docs/70_workflows/images/napari-assistant09.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant10.jpg to docs/70_workflows/images/napari-assistant10.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant11.jpg to docs/70_workflows/images/napari-assistant11.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant12.jpg to docs/70_workflows/images/napari-assistant12.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant13.jpg to docs/70_workflows/images/napari-assistant13.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant14.jpg to docs/70_workflows/images/napari-assistant14.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant15.jpg to docs/70_workflows/images/napari-assistant15.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant16.jpg to docs/70_workflows/images/napari-assistant16.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant17.jpg to docs/70_workflows/images/napari-assistant17.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant18.jpg to docs/70_workflows/images/napari-assistant18.jpg
# Copying ../BioImageAnalysisNotebooks/docs/70_workflows/images/napari-assistant1_.jpg to docs/70_workflows/images/napari-assistant1_.jpg
